# %%
# %load_ext dotenv
# %dotenv

# %%
from langchain_openai.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate, HumanMessagePromptTemplate, SystemMessagePromptTemplate
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 from langchain_openai.chat_models import ChatOpenAI
# ----> 2 from langchain.prompts import ChatPromptTemplate, HumanMessagePromptTemplate, SystemMessagePromptTemplate
#
# File ~/anaconda3/envs/langchain-env/lib/python3.10/site-packages/langchain/prompts/__init__.py:38
#      31 from typing import TYPE_CHECKING, Any
#      33 from langchain_core.example_selectors import (
#      34     LengthBasedExampleSelector,
#      35     MaxMarginalRelevanceExampleSelector,
#      36     SemanticSimilarityExampleSelector,
#      37 )
# ---> 38 from langchain_core.prompts import (
#      39     AIMessagePromptTemplate,
#      40     BaseChatPromptTemplate,
#      41     BasePromptTemplate,
#      42     ChatMessagePromptTemplate,
#      43     ChatPromptTemplate,
#      44     FewShotChatMessagePromptTemplate,
#      45     FewShotPromptTemplate,
#      46     FewShotPromptWithTemplates,
#      47     HumanMessagePromptTemplate,
#      48     MessagesPlaceholder,
#      49     PipelinePromptTemplate,
#      50     PromptTemplate,
#      51     StringPromptTemplate,
#      52     SystemMessagePromptTemplate,
#      53     load_prompt,
#      54 )
#      56 from langchain._api import create_importer
#      57 from langchain.prompts.prompt import Prompt
#
# ImportError: cannot import name 'PipelinePromptTemplate' from 'langchain_core.prompts' (/home/jas/anaconda3/envs/langchain-env/lib/python3.10/site-packages/langchain_core/prompts/__init__.py)
